# %% [markdown]
# # Workflow 2
#
# [OLD] This notebook is the first workflow as descrbed in this google document - https://docs.google.com/document/d/1qbmAjRa2V-anxj63YFFHdnovbY_U9MRi0uMAa4ZoCNg/edit.
#
# The notebook merges the predictions of different checkpoint and does accuracy assessment.

# %%
#import sys
#sys.path.append('../')
from utils import *

# import required libraries
import geopandas as gpd
import pandas as pd
import numpy as np
import os, glob, math, json
from matplotlib import pyplot as plt
from copy import deepcopy
from rtree import index
from geopandas.tools import sjoin
from shapely.geometry import box
from concurrent.futures import ThreadPoolExecutor
import time
import geoplanar
import shapely.wkt
from datetime import datetime

today = datetime.now().strftime("%y%m%d")


# change the working directory
main_dir = r"D:/2212_PlanetOrtho_FieldBoundary/ForPaper/vector/"
gt_file = r"D:\2212_PlanetOrtho_FieldBoundary\ForPaper\vector\GroundTruth\240805_GroundTruth_FieldBoundaries_PT_V2.shp"

os.chdir(main_dir)

# %% [markdown]
# ## Merge predictions from different checkpoints

# %%
# %%time

COMPACTNESS_THRESHOLD = 0.5
previous_output = '240814_Workflow1_Output_v1'
enhanced = False

# create folder
out_folder = os.path.join(main_dir, previous_output.replace('Workflow1', 'Workflow2'))
if not os.path.exists(out_folder):
    os.mkdir(out_folder)

# get all the shapefiles generated in workflow step 1
all_files = [os.path.split(file)[-1] for file in glob.glob(f'{previous_output}/*V2.gpkg')]

# filter in/ out enhanced output
if enhanced:
    all_files = [
        file
        for file in all_files
        if 'Enhanced' in file
    ]
else:
    all_files = [
        file
        for file in all_files
        if not 'Enhanced' in file
    ]

# get the file names without ViT information (to use as wildcard)
files_without_vit = sorted(list(set([
    file.replace('_vit_b','').replace('_vit_h','').replace('_vit_l','') for file in all_files
])))


# define a dataframe to store metrics
metrics_df = pd.DataFrame(columns=['File', 'Precision', 'Recall', 'F1-Score', 'Detection', 'IoU'])

# loop through all the wild cards
for n, file in enumerate(files_without_vit):
    print(f'Processing {file} {n}/{len(files_without_vit)}...')
    
    epoch = file.split('_')[0]
    size = file.split('_')[1]
    
    print(epoch, size)
    
    if enhanced:
        test_gdf = pd.concat([
            read_file_with_name(file) 
            for file in glob.glob(f'{previous_output}/*{epoch}_{size}*V2.gpkg')
            if 'Enhanced' in file
        ])
    else:
        test_gdf = pd.concat([
            read_file_with_name(file) 
            for file in glob.glob(f'{previous_output}/*{epoch}_{size}*V2.gpkg')
            if not 'Enhanced' in file
        ])
    
    test_gdf = test_gdf.explode(index_parts=True).reset_index(drop=True)
    
    test_gdf = test_gdf[['name', 'area', 'NDVI_mean', 'geometry']]
    test_gdf['ID_pred'] = test_gdf.index
    
    """
    After combining predictions, there could be overlapping polygons, deal with them
    """
    # take care of the polygons that are overlapped with their (almost!) duplicates
    test_gdf = overlap_resolution_single(test_gdf)
    
    
    # take care of the ones where small polygons are covered by large ones
    test_gdf = trim_overlaps(test_gdf, largest=True).explode(index_parts=True)
    test_gdf = test_gdf.loc[test_gdf.area > 100]
    
    # geoplanar polygon cutting creates weird shapes, get rid of those
    bounding_boxes = test_gdf.geometry.apply(lambda geom: geom.minimum_rotated_rectangle)
    test_gdf = test_gdf[test_gdf.area / bounding_boxes.area >= COMPACTNESS_THRESHOLD]
    
    # the previous step creates weird shapes, correct them
    test_gdf['geometry'] = test_gdf.buffer(-2, join_style=3).buffer(2, join_style=3)
    test_gdf = test_gdf.explode(index_parts=True)
    test_gdf = test_gdf.loc[test_gdf.area > 100]
    
    # export the combined file
    outfile1 = os.path.join(out_folder, file.replace('Workflow1', 'Workflow2'))
    test_gdf.to_file(outfile1)
# Out:
# Processing T1_12by12_10_segmented_Workflow1Merged_V2.gpkg 0/16...
# T1 12by12
# Processing T1_3by3_1_segmented_Workflow1Merged_V2.gpkg 1/16...
# T1 3by3
# Processing T1_4by4_1_segmented_Workflow1Merged_V2.gpkg 2/16...
# T1 4by4
# Processing T1_6by6_1_segmented_Workflow1Merged_V2.gpkg 3/16...
# T1 6by6
# Processing T2_12by12_10_segmented_Workflow1Merged_V2.gpkg 4/16...
# T2 12by12
# Processing T2_3by3_1_segmented_Workflow1Merged_V2.gpkg 5/16...
# T2 3by3
# Processing T2_4by4_1_segmented_Workflow1Merged_V2.gpkg 6/16...
# T2 4by4
# Processing T2_6by6_1_segmented_Workflow1Merged_V2.gpkg 7/16...
# T2 6by6
# Processing T3_12by12_10_segmented_Workflow1Merged_V2.gpkg 8/16...
# T3 12by12
# Processing T3_3by3_1_segmented_Workflow1Merged_V2.gpkg 9/16...
# T3 3by3
# Processing T3_4by4_1_segmented_Workflow1Merged_V2.gpkg 10/16...
# T3 4by4
# Processing T3_6by6_1_segmented_Workflow1Merged_V2.gpkg 11/16...
# T3 6by6
# Processing T4_12by12_10_segmented_Workflow1Merged_V2.gpkg 12/16...
# T4 12by12
# Processing T4_3by3_1_segmented_Workflow1Merged_V2.gpkg 13/16...
# T4 3by3
# Processing T4_4by4_1_segmented_Workflow1Merged_V2.gpkg 14/16...
# T4 4by4
# Processing T4_6by6_1_segmented_Workflow1Merged_V2.gpkg 15/16...
# T4 6by6
# CPU times: total: 28.7 s
# Wall time: 1min 40s

# %% [markdown]
# # Perform accuracy assessment

# %%
# %%time

# get a list of all the files
files_list = glob.glob(f"{out_folder}/*.gpkg")

# create an empty DF to store metrics
metrics_df = pd.DataFrame(columns=['File', 'Precision', 'Recall', 'F1-Score', 'Detection', 'IoU'])

# loop through all the files and caculate metrics
for n, file in enumerate(files_list):
    print(os.path.split(file)[-1], f'{n}/{len(files_list)}..')
    
    """
    prepare the ground truth shapefile
    """
    gt_gdf = gpd.read_file(gt_file)
    gt_gdf['ID_gt'] = gt_gdf.index

    # add new cols in the ground truth gdf to calculate metrics later
    for new_col in ['max_overlap_id', 'iou', 'precision', 'recall', 'f1score']:
        gt_gdf[new_col] = -1 

    # remove empty geometries
    gt_gdf = gt_gdf.loc[
        (gt_gdf.geom_type.isin(['Polygon', 'MultiPolygon']))
    ]

    """
    read the predicted data
    """
    # read the predicted file
    pred_gdf = gpd.read_file(file)
    
    """
    calculate tota area based metrics
    """
    intersection_area = gt_gdf.dissolve().intersection(pred_gdf.dissolve()).area[0]
    union_area = gt_gdf.dissolve().union(pred_gdf.dissolve()).area[0]

    precision = round(intersection_area / pred_gdf.dissolve().area[0], 3)
    recall = round(intersection_area / gt_gdf.dissolve().area[0], 3)
    f1_score = round(2 * (precision * recall) / (precision + recall), 3)

    """
    calculate number of polygons detected
    """
    # Create spatial index for test layer for faster processing
    # can't craete this inside the function because it is unnecessary time wastage
    spatial_index = index.Index()
    for i, geometry in enumerate(pred_gdf.geometry):
        if len(geometry.bounds) > 0:
            spatial_index.insert(i, geometry.bounds)

    # for each polygon in the ground truth, find polygon in the test file that has IoU greater than 0.5
    gt_gdf = gt_gdf.apply(lambda row: wflow1_iou_threshold_metrics(row, gt_gdf, deepcopy(pred_gdf), spatial_index,
                                                                  threshold=0.5), axis=1)

    # calculate the precision for this test layer (how many polygons are identified)
    detection_percentage = round(100 * gt_gdf.loc[gt_gdf['max_overlap_id'] != -1].shape[0] / gt_gdf.shape[0], 3)
    detected_iou = round(gt_gdf.loc[gt_gdf['max_overlap_id'] != -1, 'iou'].mean(), 3)

    metrics_dict = {
            'File': [os.path.split(file)[-1]],
            'Precision': [precision],
            'Recall': [recall],
            'F1-Score': [f1_score],
            'Detection': [detection_percentage],
            'IoU': [detected_iou]
        }

    metrics_df = pd.concat([
        metrics_df, 
        pd.DataFrame(metrics_dict)
    ], axis=0)

    metrics_df.to_csv(f"D:/2212_PlanetOrtho_FieldBoundary/ForPaper/tables/{today}_Workflow2Metrics_v1.csv", index=False)
# Out:
# T1_12by12_10_segmented_Workflow2Merged_V2.gpkg 0/35..
# <timed exec>:69: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# T1_12by12_Enhanced_10_segmented_Workflow2Merged_V2.gpkg 1/35..
# T1_12by12_Enhanced_4_segmented_Workflow2Merged_V2.gpkg 2/35..
# T1_3by3_1_segmented_Workflow2Merged_V2.gpkg 3/35..
# T1_3by3_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 4/35..
# T1_4by4_1_segmented_Workflow2Merged_V2.gpkg 5/35..
# T1_4by4_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 6/35..
# T1_6by6_1_segmented_Workflow2Merged_V2.gpkg 7/35..
# T1_6by6_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 8/35..
# T2_12by12_10_segmented_Workflow2Merged_V2.gpkg 9/35..
# T2_12by12_Enhanced_10_segmented_Workflow2Merged_V2.gpkg 10/35..
# T2_12by12_Enhanced_11_segmented_Workflow2Merged_V2.gpkg 11/35..
# T2_3by3_1_segmented_Workflow2Merged_V2.gpkg 12/35..
# T2_3by3_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 13/35..
# T2_4by4_1_segmented_Workflow2Merged_V2.gpkg 14/35..
# T2_4by4_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 15/35..
# T2_6by6_1_segmented_Workflow2Merged_V2.gpkg 16/35..
# T2_6by6_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 17/35..
# T3_12by12_10_segmented_Workflow2Merged_V2.gpkg 18/35..
# T3_12by12_Enhanced_10_segmented_Workflow2Merged_V2.gpkg 19/35..
# T3_12by12_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 20/35..
# T3_3by3_1_segmented_Workflow2Merged_V2.gpkg 21/35..
# T3_3by3_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 22/35..
# T3_4by4_1_segmented_Workflow2Merged_V2.gpkg 23/35..
# T3_4by4_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 24/35..
# T3_6by6_1_segmented_Workflow2Merged_V2.gpkg 25/35..
# T3_6by6_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 26/35..
# T4_12by12_10_segmented_Workflow2Merged_V2.gpkg 27/35..
# T4_12by12_Enhanced_10_segmented_Workflow2Merged_V2.gpkg 28/35..
# T4_3by3_1_segmented_Workflow2Merged_V2.gpkg 29/35..
# T4_3by3_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 30/35..
# T4_4by4_1_segmented_Workflow2Merged_V2.gpkg 31/35..
# T4_4by4_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 32/35..
# T4_6by6_1_segmented_Workflow2Merged_V2.gpkg 33/35..
# T4_6by6_Enhanced_1_segmented_Workflow2Merged_V2.gpkg 34/35..
# CPU times: total: 2min 51s
# Wall time: 8min 53s
